# %%
import pandas as pd

# %%
df=pd.read_csv("data/charging_stations.csv")
df2=pd.read_csv("data/hourly_utilization.csv")
df3=pd.read_csv("data/utilization_data.csv")

# %%
df.head(5)
# Out:
#                id                   name operator     status          address  \
# 0   B8S7YSLRUBVUO       Agerbæk Børnehus    Eviny  Available      Debelvej 25
# 1   B9OXSNAF20Z5S           Agerbæk Torv    Eviny  Available   Faaborgvej 177
# 2      Alnasenter            Alna Senter    Eviny  Available  Strømsveien 245
# 3   B8GEWDTNZ8LXC  Alstad Kro og Camping    Eviny  Available         Alstad 1
# 4  Alti-Brotorvet         Alti Brotorvet    Eviny  Available     Gangveien 10
#
#                                          description   latitude  longitude  \
# 0                          Parkering ved børnehuset.  55.603490   8.811343
# 1                                                NaN  55.600484   8.802200
# 2  Lynladere i 1 etg utendørs parkeringshus ved M...  59.926581  10.849327
# 3                                                NaN  68.272286  13.936212
# 4                                                NaN  59.046011   9.694568
#
# ...

# %%
df2.head(5)
# Out:
#       hourly_timestamp      station_id  is_available  is_occupied  \
# 0  2025-04-07T22:00:00      AkerBrygge            10            0
# 1  2025-04-07T22:00:00      Alnasenter            17            0
# 2  2025-04-07T22:00:00    Alti Svolvær            14            1
# 3  2025-04-07T22:00:00  Alti-Brotorvet            17            0
# 4  2025-04-07T22:00:00     Alti-Futura            22            0
#
#    is_out_of_order  total_connectors  occupancy_rate  availability_rate
# 0                0                14        0.000000           0.714286
# 1                0                17        0.000000           1.000000
# 2                0                15        0.066667           0.933333
# 3                0                17        0.000000           1.000000
# 4                2                24        0.000000           0.916667

# %%
df3.head(5)
# Out:
#                     timestamp     hourly_timestamp     station_id  \
# 0  2025-04-07T22:11:32.356598  2025-04-07T22:00:00  B8S7YSLRUBVUO
# 1  2025-04-07T22:11:32.356598  2025-04-07T22:00:00  B8S7YSLRUBVUO
# 2  2025-04-07T22:11:32.356598  2025-04-07T22:00:00  B8S7YSLRUBVUO
# 3  2025-04-07T22:11:32.356598  2025-04-07T22:00:00  B8S7YSLRUBVUO
# 4  2025-04-07T22:11:32.356598  2025-04-07T22:00:00  B9OXSNAF20Z5S
#
#   connector_id connector_type  power     status  is_occupied  is_available  \
# 0         AGB1      AC Type 2   22.0  Available            0             1
# 1         AGB2      AC Type 2   22.0  Available            0             1
# 2         AGB3      AC Type 2   22.0  Available            0             1
# 3         AGB4      AC Type 2   22.0  Available            0             1
# 4       ABT1-A            CCS  180.0  Available            0             1
#
#    is_out_of_order            tariff
# 0                0  DKK 2.89 per kWh
# 1                0  DKK 2.89 per kWh
# ...

# %%
df2["hourly_timestamp"].unique()
# Out:
# array(['2025-04-07 23:00:00'], dtype=object)
